# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM', 'ALVARADO']
instrument = instl[2]
m = gpitch.separation.SoSp(gpu="2", pitches=pitches, instrument=instrument, frames=224000)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
m.model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.matern12sm_1.energy.item0</td><td>[ 0.5653]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item1</td><td>[ 0.00048272]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item2</td><td>[ 0.30635109]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item3</td><td>[ 0.00126742]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item4</td><td>[ 0.09221151]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item5</td><td>[ 0.0016448]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item6</td><td>[ 0.02775836]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item7</td><td>[ 0.00041384]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item8</td><td>[ 0.00203541]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item9</td><td>[ 0.00124703]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item10</td><td>[ 0.00031808]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item11</td><td>[ 0.00062864]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item12</td><td>[  4.05974594e-05]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item13</td><td>[ 0.00021931]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item14</td><td>[  8.11918458e-05]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item0</td><td>[ 248.88960915]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item1</td><td>[ 497.39597677]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item2</td><td>[ 746.52789953]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item3</td><td>[ 995.33676914]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item4</td><td>[ 1244.34785816]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item5</td><td>[ 1493.37436176]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item6</td><td>[ 1742.0330523]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item7</td><td>[ 1987.38155352]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item8</td><td>[ 2243.01927364]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item9</td><td>[ 2493.49286413]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item10</td><td>[ 2743.55916344]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item11</td><td>[ 2980.46342162]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item12</td><td>[ 3228.20310824]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item13</td><td>[ 3491.73313529]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.frequency.item14</td><td>[ 3726.71207492]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.lengthscales</td><td>[ 0.59699732]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.matern12sm_2.energy.item0</td><td>[ 0.24573271]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_2.energy.item1</td><td>[ 0.00088471]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_2.energy.item2</td><td>[ 0.60288463]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_2.energy.item3</td><td>[ 0.01102862]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_2.ener ...

# %%
start_time = time.time()
m.optimize()
print time.time() - start_time
# Out:
# optimizing window 0
# optimizing window 1
# optimizing window 2
# optimizing window 3
# optimizing window 4
# optimizing window 5
# optimizing window 6
# optimizing window 7
# optimizing window 8
# optimizing window 9
# optimizing window 10
# optimizing window 11
# optimizing window 12
# optimizing window 13
# optimizing window 14
# optimizing window 15
# optimizing window 16
# optimizing window 17
# optimizing window 18
# optimizing window 19
# optimizing window 20
# optimizing window 21
# optimizing window 22
# optimizing window 23
# optimizing window 24
# optimizing window 25
# optimizing window 26
# optimizing window 27
# optimizing window 28
# optimizing window 29
# optimizing window 30
# optimizing window 31
# optimizing window 32
# optimizing window 33
# optimizing window 34
# optimizing window 35
# optimizing window 36
# optimizing window 37
# optimizing window 38
# optimizing window 39
# optimizing window 40
# optimizing window 41
# optimizing window 42
# optimizing window 43
# optimizing window 44
# optimizing window 45
# optimizing window 46
# optimizing window 47
# optimizing window 48
# optimizing window 49
# optimizing window 50
# optimizing window 51
# optimizing window 52
# optimizing window 53
# optimizing window 54
# optimizing window 55
# optimizing window 56
# optimizing window 57
# optimizing window 58
# optimizing window 59
# optimizing window 60
# optimizing window 61
# optimizing window 62
# optimizing window 63
# optimizing window 64
# optimizing window 65
# optimizing window 66
# optimizing window 67
# optimizing window 68
# optimizing window 69
# optimizing window 70
# optimizing window 71
# optimizing window 72
# optimizing window 73
# optimizing window 74
# optimizing window 75
# optimizing window 76
# optimizing window 77
# optimizing window 78
# optimizing window 79
# optimizing window 80
# optimizing window 81
# optimizing window 82
# optimizing window 83
# optimizing window 84
# optimizing window 85
# optimizing window 86
# optimizing window 87
# optimizing window 88
# optimizing window 89
# optimizing window 90
# optimizing window 91
# optimizing window 92
# optimizing window 93
# optimizing window 94
# optimizing window 95
# optimizing window 96
# optimizing window 97
# optimizing window 98
# optimizing window 99
# optimizing window 100
# optimizing window 101
# optimizing window 102
# optimizing window 103
# optimizing window 104
# optimizing window 105
# optimizing window 106
# optimizing window 107
# optimizing window 108
# optimizing window 109
# optimizing window 110
# optimizing window 111
# optimizing window 112
# optimizing window 113
# optimizing window 114
# optimizing window 115
# optimizing window 116
# optimizing window 117
# optimizing window 118
# optimizing window 119
# optimizing window 120
# optimizing window 121
# optimizing window 122
# optimizing window 123
# optimizing window 124
# optimizing window 125
# optimizing window 126
# optimizing window 127
# optimizing window 128
# optimizing window 129
# optimizing window 130
# optimizing window 131
# optimizing window 132
# optimizing window 133
# optimizing window 134
# optimizing window 135
# optimizing window 136
# optimizing window 137
# optimizing window 138
# optimizing window 139
# optimizing window 140
# optimizing window 141
# optimizing window 142
# optimizing window 143
# optimizing window 144
# optimizing window 145
# optimizing window 146
# optimizing window 147
# optimizing window 148
# optimizing window 149
# optimizing window 150
# optimizing window 151
# optimizing window 152
# optimizing window 153
# optimizing window 154
# optimizing window 155
# optimizing window 156
# optimizing window 157
# optimizing window 158
# optimizing window 159
# optimizing window 160
# optimizing window 161
# optimizing window 162
# optimizing window 163
# optimizing window 164
# optimizing window 165
# optimizing window 166
# optimizing window 167
# optimizing window 168
# optimizing window 169
# optimizing window 170
# optimizing window 171
# optimizing window 172
# optimizing window 173
# optimizing window 174
# optimizing window 175
# optimizing window 176
# optimizing window 177
# optimizing window 178
# optimizing window 179
# optimizing window 180
# optimizing window 181
# optimizing window 182
# optimizing window 183
# optimizing window 184
# optimizing window 185
# optimizing window 186
# optimizing window 187
# optimizing window 188
# optimizing window 189
# optimizing window 190
# optimizing window 191
# optimizing window 192
# optimizing window 193
# optimizing window 194
# optimizing window 195
# optimizing window 196
# optimizing window 197
# optimizing window 198
# optimizing window 199
# optimizing window 200
# optimizing window 201
# optimizing window 202
# optimizing window 203
# optimizing window 204
# optimizing window 205
# optimizing window 206
# optimizing window 207
# optimizing window 208
# optimizing window 209
# optimizing window 210
# optimizing window 211
# optimizing window 212
# optimizing window 213
# optimizing window 214
# optimizing window 215
# optimizing window 216
# optimizing window 217
# optimizing window 218
# optimizing window 219
# optimizing window 220
# optimizing window 221
# optimizing window 222
# 396.869245052

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
m.params
# Out:
# [[0.596997320985449, 0.14983567522562741, 0.64875652937861328],
#  [array([  5.65299998e-01,   4.82716445e-04,   3.06351092e-01,
#            1.26741974e-03,   9.22115101e-02,   1.64480498e-03,
#            2.77583639e-02,   4.13837590e-04,   2.03540744e-03,
#            1.24702987e-03,   3.18081772e-04,   6.28640368e-04,
#            4.05974594e-05,   2.19308439e-04,   8.11918458e-05]),
#   array([  2.45732710e-01,   8.84709810e-04,   6.02884626e-01,
#            1.10286150e-02,   1.32914929e-01,   3.77363261e-06,
#            3.31148200e-03,   1.79281051e-03,   2.52316082e-04,
#            9.80587235e-04,   2.09892903e-04,   1.54962785e-06,
#            3.12889684e-07,   1.57034665e-06,   1.14815394e-07]),
#   array([  4.22612793e-12,   6.04506742e-01,   5.70620803e-04,
#            3.67231181e-01,   2.12302792e-03,   2.16908910e-02,
#            3.09278769e-04,   2.03122033e-03,   1.23752846e-03,
#            1.07639857e-04,   9.91920519e-05,   6.73779441e-05,
#            1.21745803e-05,   7.88884407e-06,   5.23630652e-06])],
#  [array([  248.88960915,   497.39597677,   746.52789953,   995.33676914,
#           1244.34785816,  1493.37436176,  1742.0330523 ,  1987.38155352,
#           2243.01927364,  2493.49286413,  2743.55916344,  2980.46342162,
#           3228.20310824,  3491.73313529,  3726.71207492]),
#   array([  314.69174389,   628.50485046,   944.1404097 ,  1256.78644699,
#           1572.21234496,  1885.11779101,  2208.18509448,  2512.14810508,
#           2826.67800854,  3152.70255378,  3456.71602775,  3768.73555352,
#           4084.25526168,  4399.7749868 ,  4722.79516608]),
#   array([    9.50048932,   374.64282642,   748.54371476,  1123.37030398,
#           1501.06930264,  1872.93927098,  2251.64027936,  2619.17363526,
#           2993.18946202,  3366.710509  ,  3753.7345599 ,  4117.75736511,
#           4505.28158359,  4864.80405013,  6000.87505023])]]

# %%
m.compute_rmse()
# Out:
# 0.0043521788011007785
