# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM']
m = gpitch.separation.SoSp(gpu="2", pitches=pitches, instrument=instl[2], frames=14*16000)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
# m.model

# %%
start_time = time.time()
m.optimize()
print time.time() - start_time
# Out:
# 409.466627836

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
# m.params

# %%
m.compute_rmse()
# Out:
# 0.004352179289532499
