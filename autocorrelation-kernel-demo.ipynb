# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import gpflow
import gpitch
import time
from gpitch.myplots import plotgp

# %%
plt.rcParams["figure.figsize"] = (15, 3)
gpitch.init_settings('0');

# %%
path = "/import/c4dm-01/MAPS_original/AkPnBcht/ISOL/NO/MAPS_ISOL_NO_F_S1_M64_AkPnBcht.wav"

# %%
x, y, fs = gpitch.readaudio(path, frames=2*44100, start=28000)

# %%
plt.plot(x, y);

# %%
kernel = gpitch.samplecov.autocorr(x=y, size=2250)[0]

# %%
plt.plot(kernel);
