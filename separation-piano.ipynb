# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM', 'ALVARADO']
instrument = instl[0]
m = gpitch.separation.SoSp(gpu="0", pitches=pitches, instrument=instrument, frames=70*3200)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
m.model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.prod_1.matern12.lengthscales</td><td>[ 0.22758497]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_1.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_1.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.lengthscales</td><td>[ 0.22597939]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_2.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.lengthscales</td><td>[ 0.14186011]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_3.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.likelihood.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr></table>

# %%
m.optimize()

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
m.params
# Out:
# [[0.22758497232867628, 0.22597939251946481, 0.14186011082985425],
#  [array([ 0.8579357 ,  0.03415081,  0.00487495,  0.01645891,  0.0314905 ]),
#   array([ 0.45413203,  0.42598895,  0.04827351,  0.00585701,  0.00628415]),
#   array([ 0.71884341,  0.22987125,  0.01689548,  0.00220407,  0.00479759])],
#  [array([  246.30026611,   494.06111081,   740.95950309,   988.91251493,
#           1237.87053954]),
#   array([  310.8752203 ,   622.12226254,   934.08082482,  1561.88570889,
#           1879.96865852]),
#   array([  369.37200579,   740.44991971,  1111.96114397,  1485.57135299,
#           1861.93717875])]]

# %%
m.compute_rmse()
# Out:
# 0.0054194290076175905
