# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM', 'ALVARADO']
instrument = instl[1]
m = gpitch.separation.SoSp(gpu="1", pitches=pitches, instrument=instrument, frames=70*3200)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
m.model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.prod_1.matern12.lengthscales</td><td>[ 0.2498696]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_1.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_1.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.lengthscales</td><td>[ 0.30826925]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_2.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.lengthscales</td><td>[ 0.27583378]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_3.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr
# ...

# %%
m.optimize()

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
m.params
# Out:
# [[0.24986959831139119, 0.30826924691801139, 0.27583377509363882],
#  [array([ 0.27088971,  0.21371761,  0.13029821,  0.09822106,  0.06596864]),
#   array([ 0.43431602,  0.23835611,  0.10062845,  0.0235551 ,  0.03262067]),
#   array([ 0.61903456,  0.1173673 ,  0.13695427,  0.00785224,  0.03879287])],
#  [array([  248.32506961,   497.37852828,   747.03582677,   996.8127833 ,
#           1246.13646072]),
#   array([  312.68242389,   627.22205161,   942.15865946,  2531.07871612,
#           3179.4502668 ]),
#   array([  372.5565937 ,   748.01095752,  1123.39586237,  2643.87696525,
#           3420.11682099])]]

# %%
m.compute_rmse()
# Out:
# 0.011421821418188996
