# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM']
m = gpitch.separation.SoSp(gpu="2", pitches=pitches, instrument=instl[2], frames=14*16000, fullgp=True)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
# m.model

# %%
start_time = time.time()
m.optimize()
print time.time() - start_time
# Out:
# 18905.105128

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
# m.params

# %%
m.compute_rmse()
# Out:
# 0.0028605932445382558
