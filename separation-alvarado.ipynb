# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM', 'ALVARADO']
instrument = instl[3]
m = gpitch.separation.SoSp(gpu="3", pitches=pitches, instrument=instrument, frames=70*3200)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
m.model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.prod_1.matern12.lengthscales</td><td>[ 0.42940656]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_1.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_1.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.lengthscales</td><td>[ 0.29747807]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_2.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_2.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.lengthscales</td><td>[ 0.26648533]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.prod_3.matern12.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.prod_3.mercercosmix.variance</td><td>[ 1.]</td><td>None</td><td>[FIXED]</td></t
# ...

# %%
m.optimize()

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
m.params
# Out:
# [[0.42940656089622536, 0.29747806522739517, 0.26648532786670115],
#  [array([  3.07448134e-10,   7.96967878e-01,   9.68648091e-02,
#            6.10642711e-02,   4.01966654e-03,   4.15271949e-03,
#            3.83531579e-04,   1.08560390e-05,   4.36650852e-05,
#            2.70481920e-05,   1.27451844e-04,   7.82197379e-05,
#            3.78303294e-05,   3.61129747e-05,   2.29397140e-05]),
#   array([  4.99729039e-05,   6.07782142e-01,   2.46177887e-01,
#            9.95695752e-02,   1.24931121e-02,   3.05562450e-03,
#            3.56319647e-04,   4.70902074e-05,   3.10016720e-05,
#            4.47496645e-05,   9.95435611e-05,   5.47318477e-05,
#            4.32011407e-05,   2.69403142e-05,   4.36708621e-05]),
#   array([  1.60594728e-05,   6.13427958e-01,   1.82020963e-01,
#            1.04565270e-01,   4.58044677e-02,   2.96666435e-03,
#            6.15953322e-04,   1.73896871e-04,   4.47263541e-05,
#            3.72058263e-05,   4.13537431e-05,   1.06839253e-04,
# ...

# %%
2**5
# Out:
# 32
