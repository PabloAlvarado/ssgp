# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import gpitch
import time

# %%
pitches = [60, 64, 67]
instl = ['011PFNOM', '131EGLPM', '311CLNOM', 'ALVARADO']
instrument = instl[3]
m = gpitch.separation.SoSp(gpu="3", pitches=pitches, instrument=instrument, frames=56*4000)

# %%
m.plot_traindata()
m.plot_testdata()
m.plot_kernel()

# %%
m.model
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.matern12sm_1.energy.item0</td><td>[  1.19750227e-07]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item1</td><td>[ 0.80602442]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item2</td><td>[ 0.09794783]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item3</td><td>[ 0.06175987]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item4</td><td>[ 0.0040548]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item5</td><td>[ 0.00419592]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item6</td><td>[ 0.00038004]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item7</td><td>[  5.78299392e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.matern12sm_1.energy.item8</td>
# ...

# %%
m.optimize()

# %%
m.predict_s()

# %%
m.plot_results()
m.save_results()

# %%
m.params
# Out:
# [[1.4699425916805673, 0.78117109685588526, 0.64216521226887935],
#  [array([  1.19750227e-07,   8.06024417e-01,   9.79478344e-02,
#            6.17598665e-02,   4.05480401e-03,   4.19592040e-03,
#            3.80041079e-04,   5.78299392e-06,   3.63738148e-05,
#            2.03208182e-05,   1.20766345e-04,   7.14572457e-05,
#            3.10388912e-05,   2.90511099e-05,   1.64215844e-05]),
#   array([  3.40133697e-05,   6.19905163e-01,   2.51060058e-01,
#            1.01537170e-01,   1.27274291e-02,   3.10464821e-03,
#            3.48630101e-04,   3.54012744e-05,   1.84756773e-05,
#            3.27304215e-05,   8.84039513e-05,   4.21167537e-05,
#            3.12457934e-05,   1.40471465e-05,   3.17037609e-05]),
#   array([  4.63176167e-05,   6.28361209e-01,   1.86437440e-01,
#            1.07107015e-01,   4.69062934e-02,   3.01790172e-03,
#            6.13037328e-04,   1.64510455e-04,   2.87226551e-05,
#            2.23117445e-05,   2.52946835e-05,   9.49010201e-05,
# ...

# %%
2**5
# Out:
# 32
